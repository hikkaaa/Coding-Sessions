# %% [markdown]
# # Integration and Visualization
# - YOUR NAME: Francesca Urgese
# - YOUR VUNetID: fue400 2736482
#
# (If you do not provide your NAME and VUNetID we will not accept your submission.)
#
# **To hand in: one zip file, containing...**
# - this file, with completed tasks
# - the ontology you made in the previous assignment
# - an ontology you found on the web
# - an integrated ontology (`mapping.ttl`)

# %% [markdown]
# ## Task 1 (2 Points):  Integrating ontologies in Protégé
# Take the ontology you built for Module 4 (let’s call it ontology A), and find either a fellow student with a similar ontology or an ontology on the web on similar domain. That will be our ontology B.
#
# Create an empty ontology in Protégé (ontology C), and import both ontologies.
#
# Define at least 6 mappings as following:
#
# -    1 mapping between a class from A and a class from B using rdfs:subClassOf
# -    1 mapping between a class from A and a class from B using owl:equivalentClass
# -    1 mapping between a property from A and a property from B using rdfs:subPropertyOf
# -    1 mapping between a property from A and a property from B using either owl:equivalentProperty, owl:disjointProperty, owl:inverseOf, or owl:propertyChainAxiom
# -    1 mapping between an individual from A and an individual from B using owl:differentFrom
# -    1 mapping between an individual from A and an individual from B using owl:sameAs
#
# The combined ontology should be **consistent**.
#
# Save the ontology as Turtle, where the filename is ‘`mapping.ttl`’
#
# Add all three ontologies to the ZIP file of this assignment, leaving preserved the original file names of the ontologies.

# %%
print(open('mapping.ttl').read())
# Out:
# @prefix : <http://www.semanticweb.org/francesca/mapping#> .
# @prefix st: <http://www.semanticweb.org/francesca/mapping/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix xml: <http://www.w3.org/XML/1998/namespace> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @base <http://www.semanticweb.org/francesca/mapping> .
#
# <http://www.semanticweb.org/francesca/mapping> rdf:type owl:Ontology ;
#                                                 owl:imports <http://www.semanticweb.org/francesca/familly-relations> ,
#                                                             <http://www.semanticweb.org/user/ontologies/2020/3/myFamily17002953> .
#
# #################################################################
# #    Object Properties
# #################################################################
#
# ###  http://www.semanticweb.org/francesca/familly-relations/Daughter-Of
# <http://www.semanticweb.org/francesca/familly-relations/Daughter-Of> owl:equivalentProperty <http://www.semanticweb.org/user/ontologies/2020/3/myFamily17002953#OWLObjectProperty_78e73a93_155f_40da_a52d_75cae1d3a3a7> .
#
#
# ###  http://www.semanticweb.org/francesca/familly-relations/Has-Daughter
# <http://www.semanticweb.org/francesca/familly-relations/Has-Daughter> rdfs:subPropertyOf <http://www.semanticweb.org/user/ontologies/2020/3/myFamily17002953#OWLObjectProperty_e2449651_b063_4d13_bf45_8f1563c95d68> .
#
#
# ###  http://www.semanticweb.org/francesca/familly-relations/Has-Son
# <http://www.semanticweb.org/francesca/familly-relations/Has-Son> rdfs:subPropertyOf <http://www.semanticweb.org/user/ontologies/2020/3/myFamily17002953#OWLObjectProperty_e2449651_b063_4d13_bf45_8f1563c95d68> .
#
#
# ###  http://www.semanticweb.org/user/ontologies/2020/3/myFamily17002953#OWLObjectProperty_78e73a93_155f_40da_a52d_75cae1d3a3a7
#
# #################################################################
# #    Classes
# #################################################################
#
# ###  http://www.semanticweb.org/francesca/familly-relations/Child
# <http://www.semanticweb.org/francesca/familly-relations/Child> owl:equivalentClass <http://www.semanticweb.org/user/ontologies/2020/3/myFamily17002953#OWLClass_38c4ec00_72e6_42ca_9a3e_e2674c9f39cc> ;
#                                                                rdfs:subClassOf <http://www.semanticweb.org/user/ontologies/2020/3/myFamily17002953#OWLClass_54242f6f_b764_4137_9c14_6c4967878338> .
#
#
# ###  http://www.semanticweb.org/user/ontologies/2020/3/myFamily17002953#OWLClass_38c4ec00_72e6_42ca_9a3e_e2674c9f39cc
#
# #################################################################
# #    Individuals
# #################################################################
#
# ###  http://www.semanticweb.org/francesca/familly-relations/Alessia
# <http://www.semanticweb.org/francesca/familly-relations/Alessia> owl:sameAs <http://www.semanticweb.org/user/ontologies/2020/3/myFamily17002953#OWLNamedIndividual_c0fab07c_0d78_43fd_9dbd_3047fb9864f0> .
#
#
# ###  http://www.semanticweb.org/user/ontologies/2020/3/myFamily17002953#OWLNamedIndividual_c0fab07c_0d78_43fd_9dbd_3047fb9864f0
#
# #################################################################
# #    General axioms
# #################################################################
#
# [ rdf:type owl:AllDifferent ;
#   owl:distinctMembers ( <http://www.semanticweb.org/francesca/familly-relations/Valeria>
#                         <http://www.semanticweb.org/user/ontologies/2020/3/myFamily17002953#OWLNamedIndividual_c0fab07c_0d78_43fd_9dbd_3047fb9864f0>
#                       )
# ] .
#
#
# ###  Generated by the OWL API (version 4.5.9.2019-02-01T07:24:44Z) https://github.com/owlcs/owlapi

# %% [markdown]
# ## Task 2 (1 Point):  Explain your mapping
#
# Please explain in a few sentences in the text field below the mapping you made in the previous question:
#
# - **First Mapping** \
# **ex:Child owl:EquivalentClass ex:Sibling** \
# Looking at the two ontologies, we can see that the classes Child and Sibling are equivalent. They have same subclasses and the requisites to be part of these classes are the same.
#
# - **Second Mapping**\
# **ex:Child rdfs:subClassOf ex:DomainEntity** \
# Since class Child is equivalent to Sibling, it can be defined to be a subclass of class DomainEntity as well.
#
# - **Third Mapping**\
# **ex:DaughterOf owl:equivalentProperty ex:has-Parent** \
# These two property are equivalent since saying that you are the daugher of someone or saying that you have someone has a parent has the same meaning.
#
# - **Fourth Mapping**\
# **ex:has-Son rdfs:subPropertyOf ex:has-Relation** \
# Ontology B did not specify any has-Son or has-Daughter property, they are implicitely included in 'BloodRelation'. However, as they are present in ontology A, we can set them to be subproperties of the Has-Relation property.
#
# - **Fifth Mapping**\
# **ex:Valeria owl:differentFrom Debora**\
# Even though Valeria and Debora have many similarities, we do not want the reasoner (or any user looking at the ontology) infer that they might be the same individual. For this not to be the case, we set Valeria as different from Debora.
#
# - **Sixth Mapping**\
# **ex:Alessia owl:sameAs ex:Debora**\
# In ontology A, individual Alessia is not defined to be member of any class and just few data properties were assigned to it. Thanks to this vague definition of this individual, we can state that it is the same as individual Debora from ontology B, keeping the overall ontology C to be consistent.

# %% [markdown]
# ## Task 3 (2 points):  Integration with SPARQL
#
# Before starting this task, make sure to watch the demo given in Lecture 10.
#
# Follow these instructions to complete this task:
#
# 1.    Open your GraphDB workbench.
# 2.    Create a new repository called assignment-5, and import your ontology A into this repository (you must have at least provided the Ontology A in the previous question).
# 3.    Given your initial ontology A and the domain it covers, find on the Web a public SPARQL endpoint that provides similar or complementary information (e.g. DBpedia, Wikidata, LinkedGeoData).
# 4.    From the SPARQL interface in GraphDB, write a SELECT query that you can use to retrieve this complementary or similar information from the SPARQL endpoint.
# 5.    Now also from the SPARQL interface in GraphDB, write an INSERT query to define mappings between the retrieved data and your ontology A. These mappings can be between classes in your ontology and classes in the retrieved data (e.g. using rdfs:subClassOf), between instances (e.g. using owl:sameAs), or between instances and classes (e.g. using rdf:type).
# 6.    After creating the mappings in GraphDB, export your RDF data, and check in Protégé if your ontology is consistent.
# 7.    If your ontology is still consistent, paste here both the SELECT query (step 4) and the INSERT query (step 5) that created these mappings. Otherwise, go back to Step 4.
#
# * fare tipo query che conta il numero di tuoi parenti che vivono a roma
# SELECT:
# ```sparql
# SELECT ...
# ```
#
# INSERT:
# ```sparql
# INSERT ...
# ```

# %%
# %load_ext ipython_sparql_pandas

# %% [markdown]
# ## Task 4 (2 point). Pandas Plotting
# First, make sure that `vuDataset.ttl` is loaded in GraphDb as the `repo-vu` repository.
#
# - **Task 4a:** Make a horizontal bar chart from the `courseload` dataframe
# - **Task 4b:** Write a new SPARQL query for DBpedia and create an interesting chart from it

# %%
# %%sparql http://localhost:7200/repositories/repo-vu -s courseload
# PREFIX vu: <http://example.org/vu/>
#
# SELECT ?teacher (COUNT(*) as ?courses) {
#     ?teacher vu:teaches ?o .
# } GROUP BY ?teacher
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File c:\Users\francesca\anaconda3\envs\100days\lib\urllib\request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File c:\Users\francesca\anaconda3\envs\100days\lib\http\client.py:1282, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1281 """Send a complete request to the server."""
# -> 1282 self._send_request(method, url, body, headers, encode_chunked)
#
# File c:\Users\francesca\anaconda3\envs\100days\lib\http\client.py:1328, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1327     body = _encode(body, 'body')
# -> 1328 self.endheaders(body, encode_chunked=encode_chunked)
#
# File c:\Users\francesca\anaconda3\envs\100days\lib\http\client.py:1277, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1276     raise CannotSendHeader()
# -> 1277 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File c:\Users\francesca\anaconda3\envs\100days\lib\http\client.py:1037, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1036 del self._buffer[:]
# -> 1037 self.send(msg)
#    1039 if message_body is not None:
#    1040
#    1041     # create a consistent interface to message_body
#
# File c:\Users\francesca\anaconda3\envs\100days\lib\http\client.py:975, in HTTPConnection.send(self, data)
#     974 if self.auto_open:
# --> 975     self.connect()
#     976 else:
#
# File c:\Users\francesca\anaconda3\envs\100days\lib\http\client.py:941, in HTTPConnection.connect(self)
#     940 sys.audit("http.client.connect", self, self.host, self.port)
# --> 941 self.sock = self._create_connection(
#     942     (self.host,self.port), self.timeout, self.source_address)
#     943 # Might fail in OSs that don't implement TCP_NODELAY
#
# File c:\Users\francesca\anaconda3\envs\100days\lib\socket.py:845, in create_connection(address, timeout, source_address)
#     844 try:
# --> 845     raise err
#     846 finally:
#     847     # Break explicitly a reference cycle
#
# File c:\Users\francesca\anaconda3\envs\100days\lib\socket.py:833, in create_connection(address, timeout, source_address)
#     832     sock.bind(source_address)
# --> 833 sock.connect(sa)
#     834 # Break explicitly a reference cycle
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# c:\Users\francesca\Documents\code\100-Days-Of-Coding\ASSIGNMENT 5\Integration and Visualization.ipynb Cell 8 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/francesca/Documents/code/100-Days-Of-Coding/ASSIGNMENT%205/Integration%20and%20Visualization.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> get_ipython().run_cell_magic('sparql', 'http://localhost:7200/repositories/repo-vu -s courseload', 'PREFIX vu: <http://example.org/vu/>\n\nSELECT ?teacher (COUNT(*) as ?courses) {\n    ?teacher vu:teaches ?o .\n} GROUP BY ?teacher\n')
#
# File c:\Users\francesca\anaconda3\envs\100days\lib\site-packages\IPython\core\interactiveshell.py:2358, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2356 with self.builtin_trap:
#    2357     args = (magic_arg_s, cell)
# -> 2358     result = fn(*args, **kwargs)
#    2359 return result
#
# File c:\Users\francesca\anaconda3\envs\100days\lib\site-packages\ipython_sparql_pandas\sparql.py:29, in sparql(line, cell, local_ns)
#      27     cell = cell % local_ns[args.params]
#      28 client.setQuery(cell)
# ---> 29 results = client.query().convert()
#      30 df = df_results(results)
#      32 if args.save:
#
# File c:\Users\francesca\anaconda3\envs\100days\lib\site-packages\SPARQLWrapper\Wrapper.py:960, in SPARQLWrapper.query(self)
#     942 def query(self) -> "QueryResult":
#     943     """
#     944     Execute the query.
#     945     Exceptions can be raised if either the URI is wrong or the HTTP sends back an error (this is also the
#    (...)
#     958     :rtype: :class:`QueryResult` instance
#     959     """
# --> 960     return QueryResult(self._query())
#
# File c:\Users\francesca\anaconda3\envs\100days\lib\site-packages\SPARQLWrapper\Wrapper.py:926, in SPARQLWrapper._query(self)
#     924         response = urlopener(request, timeout=self.timeout)
#     925     else:
# --> 926         response = urlopener(request)
#     927     return response, self.returnFormat
#     928 except urllib.error.HTTPError as e:
#
# File c:\Users\francesca\anaconda3\envs\100days\lib\urllib\request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File c:\Users\francesca\anaconda3\envs\100days\lib\urllib\request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     516     req = meth(req)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#     522 meth_name = protocol+"_response"
#
# File c:\Users\francesca\anaconda3\envs\100days\lib\urllib\request.py:536, in OpenerDirector._open(self, req, data)
#     533     return result
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#     539     return result
#
# File c:\Users\francesca\anaconda3\envs\100days\lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File c:\Users\francesca\anaconda3\envs\100days\lib\urllib\request.py:1377, in HTTPHandler.http_open(self, req)
#    1376 def http_open(self, req):
# -> 1377     return self.do_open(http.client.HTTPConnection, req)
#
# File c:\Users\francesca\anaconda3\envs\100days\lib\urllib\request.py:1351, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1348         h.request(req.get_method(), req.selector, req.data, headers,
#    1349                   encode_chunked=req.has_header('Transfer-encoding'))
#    1350     except OSError as err: # timeout error
# -> 1351         raise URLError(err)
#    1352     r = h.getresponse()
#    1353 except:
#
# URLError: <urlopen error [WinError 10061] No connection could be made because the target machine actively refused it>

# %%
# Pandas visualization: https://pandas.pydata.org/docs/user_guide/visualization.html
courseload.set_index('teacher', inplace=True)
courseload['courses'].plot.pie()
# Out:
# <AxesSubplot:ylabel='courses'>

# %%
### Task 4a (1 point): Make a horizontal bar chart from the `courseload` dataframe
# Pandas visualization: https://pandas.pydata.org/docs/user_guide/visualization.html
courseload['courses'].plot.barh()
# Out:
# <AxesSubplot:ylabel='teacher'>

# %%
# %%sparql http://localhost:7200/repositories/repo-vu -s courseload
# PREFIX vu: <http://example.org/vu/>
#
# SELECT ?course (COUNT(*) as ?teachers)
# WHERE {?teacher vu:teaches ?course}
# GROUP BY ?course
# ORDER BY DESC(?course)
# LIMIT 10
# Out:
#                           course  teachers
# 0  http://example.org/vu/courseE         1
# 1  http://example.org/vu/courseD         1
# 2  http://example.org/vu/courseC         2
# 3  http://example.org/vu/courseB         2
# 4  http://example.org/vu/courseA         3

# %%
# Pandas visualization: https://pandas.pydata.org/docs/user_guide/visualization.html
courseload.set_index('course', inplace=True)
courseload['teachers'].plot.bar(xlabel = 'Course', ylabel = 'Number Of Teachers')
# Out:
# <AxesSubplot:xlabel='Course', ylabel='Number Of Teachers'>

# %% [markdown]
# ## Task 5 (1 point). Pandas styling
# Below is some code that shows a colored table.
#
# **Task:** Add a column with the percentage of the area of the country that is water.
# The background color of this column depend on its value: it should be greener if more of the country is land, and bluer if more of the country is water.

# %%
# %%sparql http://dbpedia.org/sparql/ -q -s dbpedia_countries
# PREFIX dct: <http://purl.org/dc/terms/>
# PREFIX dcb: <http://dbpedia.org/resource/Category:>
# PREFIX dbo: <http://dbpedia.org/ontology/>
#
# SELECT DISTINCT ?name ?area_100k_km2 ?giniCoefficient ?percentageOfAreaWater WHERE {
#     ?country
#         dct:subject dcb:Current_member_states_of_the_United_Nations ;
#         dbo:area ?area ; # area is stated in m^2
#         dbo:giniCoefficient ?giniCoefficient ;
#         dbo:percentageOfAreaWater ?percentageOfAreaWater;
#         rdfs:label ?name.
#
#     BIND (ROUND(?area/100000000000) AS ?area_100k_km2)
#     FILTER(LANG(?name) = 'en')
# }
# ORDER BY DESC(?area_100k_km2)
# LIMIT 50

# %%
# Styling: https://pandas.pydata.org/docs/user_guide/style.html
# Using CSS Hue-Saturation-Level colors: https://www.w3schools.com/colors/colors_hsl.asp

def gini_color(gini):
    return f'background: hsl({100 - gini}, 100%, 50%)' 

def area_water_color(percentage):
    return f'background: hsl({175 - percentage}, 100%, 50%)'

dbpedia_countries.style \
    .applymap(gini_color, subset=(slice(None), "giniCoefficient"))\
    .applymap(area_water_color, subset=(slice(None), "percentageOfAreaWater"))
# Out:
# <style type="text/css">
# #T_630a6_row0_col2 {
#   background: hsl(62.5, 100%, 50%);
# }
# #T_630a6_row0_col3 {
#   background: hsl(162.0, 100%, 50%);
# }
# #T_630a6_row1_col2 {
#   background: hsl(69.7, 100%, 50%);
# }
# #T_630a6_row1_col3 {
#   background: hsl(163.24, 100%, 50%);
# }
# #T_630a6_row2_col2 {
#   background: hsl(51.5, 100%, 50%);
# }
# #T_630a6_row2_col3 {
#   background: hsl(170.34, 100%, 50%);
# }
# #T_630a6_row3_col2 {
#   background: hsl(53.3, 100%, 50%);
# }
# #T_630a6_row3_col3 {
#   background: hsl(172.2, 100%, 50%);
# }
# #T_630a6_row4_col2 {
#   background: hsl(46.6, 100%, 50%);
# }
# #T_630a6_row4_col3 {
#   background: hsl(174.35, 100%, 50%);
# }
# #T_630a6_row5_col2 {
#   background: hsl(67.5, 100%, 50%);
# }
# #T_630a6_row5_col3 {
#   background: hsl(173.21, 100%, 50%);
# }
# #T_630a6_row6_col2 {
#   background: hsl(64.3, 100%, 50%);
# }
# #T_630a6_row6_col3 {
#   background: hsl(165.4, 100%, 50%);
# }
# #T_630a6_row7_col2 {
#   background: hsl(57.1, 100%, 50%);
# }
# #T_630a6_row7_col3 {
#   background: hsl(173.43, 100%, 50%);
# }
# #T_630a6_row8_col2 {
#   background: hsl(72.5, 100%, 50%);
# }
# #T_630a6_row8_col3 {
#   background: hsl(173.3, 100%, 50%);
# }
# #T_630a6_row9_col2 {
#   background: hsl(72.4, 100%, 50%);
# }
# #T_630a6_row9_col3 {
#   background: hsl(173.9, 100%, 50%);
# }
# #T_630a6_row10_col2 {
#   background: hsl(57.9, 100%, 50%);
# }
# #T_630a6_row10_col3 {
#   background: hsl(171.68, 100%, 50%);
# }
# #T_630a6_row11_col2 {
#   background: hsl(54.1, 100%, 50%);
# }
# #T_630a6_row11_col3, #T_630a6_row20_col3 {
#   background: hsl(174.3, 100%, 50%);
# }
# #T_630a6_row12_col2 {
#   background: hsl(58.2, 100%, 50%);
# }
# #T_630a6_row12_col3 {
#   background: hsl(173.42, 100%, 50%);
# }
# #T_630a6_row13_col2 {
#   background: hsl(67.3, 100%, 50%);
# }
# #T_630a6_row13_col3 {
#   background: hsl(174.33, 100%, 50%);
# }
# #T_630a6_row14_col2 {
#   background: hsl(58.0, 100%, 50%);
# }
# #T_630a6_row14_col3 {
#   background: hsl(173.37, 100%, 50%);
# }
# #T_630a6_row15_col2 {
#   background: hsl(66.0, 100%, 50%);
# }
# #T_630a6_row15_col3 {
#   background: hsl(174.98, 100%, 50%);
# }
# #T_630a6_row16_col2 {
#   background: hsl(56.7, 100%, 50%);
# }
# #T_630a6_row16_col3 {
#   background: hsl(173.1, 100%, 50%);
# }
# #T_630a6_row17_col2 {
#   background: hsl(58.5, 100%, 50%);
# }
# #T_630a6_row17_col3 {
#   background: hsl(174.59, 100%, 50%);
# }
# #T_630a6_row18_col2, #T_630a6_row46_col2 {
#   background: hsl(67.0, 100%, 50%);
# }
# #T_630a6_row18_col3 {
#   background: hsl(173.4, 100%, 50%);
# }
# #T_630a6_row19_col2 {
#   background: hsl(37.0, 100%, 50%);
# }
# #T_630a6_row19_col3 {
#   background: hsl(174.62, 100%, 50%);
# }
# #T_630a6_row20_col2 {
#   background: hsl(65.0, 100%, 50%);
# }
# #T_630a6_row21_col2 {
#   background: hsl(58.4, 100%, 50%);
# }
# #T_630a6_row21_col3 {
#   background: hsl(173.71, 100%, 50%);
# }
# #T_630a6_row22_col2 {
#   background: hsl(48.7, 100%, 50%);
# }
# #T_630a6_row22_col3, #T_630a6_row32_col3 {
#   background: hsl(172.9, 100%, 50%);
# }
# #T_630a6_row23_col2 {
#   background: hsl(68.5, 100%, 50%);
# }
# #T_630a6_row23_col3 {
#   background: hsl(174.368, 100%, 50%);
# }
# #T_630a6_row24_col2 {
#   background: hsl(67.4, 100%, 50%);
# }
# #T_630a6_row24_col3 {
#   background: hsl(174.97, 100%, 50%);
# }
# #T_630a6_row25_col2 {
#   background: hsl(64.9, 100%, 50%);
# }
# #T_630a6_row25_col3 {
#   background: hsl(173.6, 100%, 50%);
# }
# #T_630a6_row26_col2 {
#   background: hsl(55.2, 100%, 50%);
# }
# #T_630a6_row26_col3 {
#   background: hsl(171.8, 100%, 50%);
# }
# #T_630a6_row27_col2, #T_630a6_row33_col2 {
#   background: hsl(68.4, 100%, 50%);
# }
# #T_630a6_row27_col3, #T_630a6_row33_col3 {
#   background: hsl(172.14, 100%, 50%);
# }
# #T_630a6_row28_col2 {
#   background: hsl(59.5, 100%, 50%);
# }
# #T_630a6_row28_col3 {
#   background: hsl(168.6, 100%, 50%);
# }
# #T_630a6_row29_col2 {
#   background: hsl(54.3, 100%, 50%);
# }
# #T_630a6_row29_col3 {
#   background: hsl(172.8, 100%, 50%);
# }
# #T_630a6_row30_col2, #T_630a6_row47_col2 {
#   background: hsl(58.1, 100%, 50%);
# }
# #T_630a6_row30_col3 {
#   background: hsl(172.97, 100%, 50%);
# }
# #T_630a6_row31_col2 {
#   background: hsl(42.9, 100%, 50%);
# }
# #T_630a6_row31_col3 {
#   background: hsl(174.0, 100%, 50%);
# }
# #T_630a6_row32_col2 {
#   background: hsl(54.0, 100%, 50%);
# }
# #T_630a6_row34_col2, #T_630a6_row48_col2 {
#   background: hsl(59.7, 100%, 50%);
# }
# #T_630a6_row34_col3, #T_630a6_row48_col3 {
#   background: hsl(174.944, 100%, 50%);
# }
# #T_630a6_row35_col2 {
#   background: hsl(69.3, 100%, 50%);
# }
# #T_630a6_row35_col3 {
#   background: hsl(171.94, 100%, 50%);
# }
# #T_630a6_row36_col2 {
#   background: hsl(73.4, 100%, 50%);
# }
# #T_630a6_row36_col3 {
#   background: hsl(168.0, 100%, 50%);
# }
# #T_630a6_row37_col2 {
#   background: hsl(46.7, 100%, 50%);
# }
# #T_630a6_row37_col3 {
#   background: hsl(172.3, 100%, 50%);
# }
# #T_630a6_row38_col2 {
#   background: hsl(43.7, 100%, 50%);
# }
# #T_630a6_row38_col3 {
#   background: hsl(175.0, 100%, 50%);
# }
# #T_630a6_row39_col2 {
#   background: hsl(70.8, 100%, 50%);
# }
# #T_630a6_row39_col3 {
#   background: hsl(174.14, 100%, 50%);
# }
# #T_630a6_row40_col2 {
#   background: hsl(57.4, 100%, 50%);
# }
# #T_630a6_row40_col3 {
#   background: hsl(174.1, 100%, 50%);
# }
# #T_630a6_row41_col2, #T_630a6_row43_col2 {
#   background: hsl(59.2, 100%, 50%);
# }
# #T_630a6_row41_col3 {
#   background: hsl(172.7, 100%, 50%);
# }
# #T_630a6_row42_col2 {
#   background: hsl(73.1, 100%, 50%);
# }
# #T_630a6_row42_col3 {
#   background: hsl(166.63, 100%, 50%);
# }
# #T_630a6_row43_col3 {
#   background: hsl(170.1, 100%, 50%);
# }
# #T_630a6_row44_col2 {
#   background: hsl(53.4, 100%, 50%);
# }
# #T_630a6_row44_col3 {
#   background: hsl(174.43, 100%, 50%);
# }
# #T_630a6_row45_col2 {
#   background: hsl(65.1, 100%, 50%);
# }
# #T_630a6_row45_col3 {
#   background: hsl(174.6, 100%, 50%);
# }
# #T_630a6_row46_col3 {
#   background: hsl(174.11, 100%, 50%);
# }
# #T_630a6_row47_col3 {
#   background: hsl(173.0, 100%, 50%);
# }
# #T_630a6_row49_col2 {
#   background: hsl(70.3, 100%, 50%);
# }
# #T_630a6_row49_col3 {
#   background: hsl(173.73, 100%, 50%);
# }
# </style>
# <table id="T_630a6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_630a6_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_630a6_level0_col1" class="col_heading level0 col1" >area_100k_km2</th>
#       <th id="T_630a6_level0_col2" class="col_heading level0 col2" >giniCoefficient</th>
#       <th id="T_630a6_level0_col3" class="col_heading level0 col3" >percentageOfAreaWater</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_630a6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_630a6_row0_col0" class="data row0 col0" >Russia</td>
#       <td id="T_630a6_row0_col1" class="data row0 col1" >171.000000</td>
#       <td id="T_630a6_row0_col2" class="data row0 col2" >37.500000</td>
#       <td id="T_630a6_row0_col3" class="data row0 col3" >13.000000</td>
#     </tr>
#     <tr>
#       <th id="T_630a6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_630a6_row1_col0" class="data row1 col0" >Canada</td>
#       <td id="T_630a6_row1_col1" class="data row1 col1" >100.000000</td>
#       <td id="T_630a6_row1_col2" class="data row1 col2" >30.300000</td>
#       <td id="T_630a6_row1_col3" class="data row1 col3" >11.760000</td>
#     </tr>
#     <tr>
#       <th id="T_630a6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_630a6_row2_col0" class="data row2 col0" >United States</td>
#       <td id="T_630a6_row2_col1" class="data row2 col1" >98.000000</td>
#       <td id="T_630a6_row2_col2" class="data row2 col2" >48.500000</td>
#       <td id="T_630a6_row2_col3" class="data row2 col3" >4.660000</td>
#     </tr>
#     <tr>
#       <th id="T_630a6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_630a6_row3_col0" class="data row3 col0" >China</td>
#       <td id="T_630a6_row3_col1" class="data row3 col1" >96.000000</td>
#       <td id="T_630a6_row3_col2" class="data row3 col2" >46.700000</td>
#       <td id="T_630a6_row3_col3" class="data row3 col3" >2.800000</td>
#     </tr>
#     <tr>
#       <th id="T_630a6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_630a6_row4_col0" class="data row4 col0" >Brazil</td>
#       <td id="T_630a6_row4_col1" class="data row4 col1" >85.000000</td>
#       <td id="T_630a6_row4_col2" class="data row4 col2"

# %% [markdown]
# # Task 6 (2 points): Folium Map
#
# Below is some code that makes a map.
#
# **Task:** Make the markers bigger depending on the population of the capital (but keep it readable!)
#
# Tip: use the auto-complete functionality of http://query.wikidata.org
#
# **Bonus (0 points, but lots of honor):** Why does London show up on the map?

# %%
# %%sparql http://query.wikidata.org/sparql -q -s capitals
# SELECT ?capitalLabel ?coords ?populationTotal WHERE {
#     ?country
#         wdt:P463 wd:Q458 ; # member of: European Union
#         wdt:P36 ?capital . # capital: ?capital
#
#     ?capital
#         wdt:P625 ?coords ; # coordinate location: ?coords
#         wdt:P1082 ?populationTotal .
#
#     # Using Wikidata-only label service
#     SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
# }

# %%
# %pip install folium

# %%
import folium
# Extract latitude and longitude from coordinates in Well-Known Text (WKT) format
capitals_coords = capitals.join(capitals.coords.str.extract('Point\((?P<lon>\S+) (?P<lat>\S+)\)').astype(float))

middle = [capitals_coords['lat'].mean(), capitals_coords['lon'].mean()]
m = folium.Map(location=middle, zoom_start=4.2)
for _, row in capitals_coords.iterrows():
    folium.CircleMarker(
        location=[row['lat'], row['lon']],
        radius= 0.0000025*int(row['populationTotal']),
        popup= row['capitalLabel'],
        color="#3186cc",
        fill=True,
        fill_color="#3186cc",
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_68328e78f834597961f3620cf7772e22 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_68328e78f834597961f3620cf7772e22&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_68328e78f834597961f3620cf7772e22 = L.map(
#                 &quot;map_68328e78f834597961f3620cf7772e22&quot;,
#                 {
#                     center: [48.387085693172416, 14.374156911620691],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4.2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_493e9e5e97438a7113c49003c8794e79 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_68328e78f834597961f3620cf7772e22);
#
#
#             var circle_marker_07a52c0cb43ef6df0e72c27a67265087 = L.circleMarker(
#                 [52.516666666, 13.383333333],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3186cc&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 9.16022, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_68328e78f834597961f3620cf7772e22);
#
#
#         var popup_175435d0140efe3d3d8a971000e75b04 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d3d736fbe30814a4a4faf528a5e93436 = $(`&lt;div id=&quot;html_d3d736fbe30814a4a4faf528a5e93436&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Berlin&lt;/div&gt;`)[0];
#                 popup_175435d0140efe3d3d8a971000e75b04.setContent(html_d3d736fbe30814a4a4faf528a5e93436);
#
#
#
#         circle_marker_07a52c0cb43ef6df0e72c27a67265087.bindPopup(popup_175435d0140efe3d3d8a971000e75b04)
#         ;
#
#
#
#
#             var circle_marker_f95feab9c3e739e638aa2dd6a69f9d5c = L.circleMarker(
#                 [51.507222222, -0.1275],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3186cc&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 22.270202500000003, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_68328e78f834597961f3620cf7772e22);
#
#
#         var popup_4a21b29223ec94986c5d09c541eae5c4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9d44eee433f9d913b434ef585039acd7 = $(`&lt;div id=&quot;html_9d44eee433f9d913b434ef585039acd7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;London&lt;/div&gt;`)[0];
#                 popup_4a21b29223ec94986c5d09c541eae5c4.setContent(html_9d44eee433f9d913b434ef585039acd7);
#
#
#
#         circle_marker_f95feab9c3e739e638aa2dd6a69f9d5c.bindPopup(popup_4a21b29223ec94986c5d09c541eae5c4)
#         ;
#
#
#
#
#             var circle_marker_7d59aa3a5c8241cd226bdc8e239a0eee = L.circleMarker(
#                 [48.856944444, 2.351388888],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3186cc&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5.4135575000000005, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_68328e78f834597961f3620cf7772e22);
#
#
#         var popup_75e027ece327cad3c9f3b13e02bdb450 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0a0f2d836457dfcf783304e58dd2b285 = $(`&lt;div id=&quot;html_0a0f2d836457dfcf783304e58dd2b285&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Paris&lt;/div&gt;`)[0];
#                 popup_75e027ece327cad3c9f3b13e02bdb450.setContent(html_0a0f2d836457dfcf783304e58dd2b285);
#
#
#
#         circle_marker_7d59aa3a5c8241cd226bdc8e239a0eee.bindPopup(popup_75e027ece327cad3c9f3b13e02bdb450)
#         ;
#
#
#
#
#             var circle_marker_85fd51917643add459313663fcff1ac1 = L.circleMarker(
#                 [54.687222222, 25.28],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3186cc&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0

# %% [markdown]
# The result should look a bit like this:
#
# ![result.png](data:image/png;base64,...)
